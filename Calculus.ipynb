# %% [markdown]
# ### Limits

# %% [markdown]
# ### Infinitesimals

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(-10,10,1000) #start,finish,n points
#x

# %% [markdown]
# ### y = x^2 + 2*x + 2

# %%
y = x*x + 2*x + 2
#y

# %%
fig,ax = plt.subplots()
_=ax.plot(x,y)

# %%
fig,ax = plt.subplots()
ax.set_xlim([-2,0])
ax.set_ylim([0,2])
_=ax.plot(x,y)

# %%
fig,ax = plt.subplots()
ax.set_xlim([-1.5,-0.5])
ax.set_ylim([0.5,1.5])
_=ax.plot(x,y)

# %%
fig,ax = plt.subplots()
ax.set_xlim([-1.1,-0.9])
ax.set_ylim([0.9,1.1])
_=ax.plot(x,y)

# %%
fig,ax = plt.subplots()
ax.set_xlim([-1.01,-0.99])
ax.set_ylim([0.99,1.01])
_=ax.plot(x,y)

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.linspace(-10,10,1000)
y = x*x+2*x+2
fig, ax = plt.subplots()
plt.axvline(x=0,color='lightgray')
plt.axhline(y=0,color='lightgray')
plt.xlim(-5,10)
plt.ylim(-10,80)
plt.axvline(x=5,color='purple',linestyle='--')
plt.axhline(y=37,color='purple',linestyle='--')
_ = ax.plot(x,y)

# %% [markdown]
# ### $$\lim_{x \to 1} \frac{x^2 - 1}{x - 1}$$

# %%
def my_fxn(my_x):
    my_y = (my_x**2-1) / (my_x-1)
    return my_y

# %%
my_fxn(2)
# Out:
# 3.0

# %%
my_fxn(0.9)
# Out:
# 1.9

# %%
my_fxn(0.999)
# Out:
# 1.9989999999999712

# %%
my_fxn(1.001)
# Out:
# 2.0009999999999177

# %% [markdown]
# ### $$\lim_{x \to 0} \frac{\text{sin } x}{x}$$

# %%
def sin_fxn(my_x):
    my_y = np.sin(my_x) / my_x
    return my_y

# %%
#sin_fxn(0)

# %%
sin_fxn(0.1)
# Out:
# 0.9983341664682815

# %%
sin_fxn(0.01)
# Out:
# 0.9999833334166665

# %%
sin_fxn(-0.1)
# Out:
# 0.9983341664682815

# %%
sin_fxn(-0.001)
# Out:
# 0.9999998333333416

# %%
y = sin_fxn(x)

# %%
fig, ax = plt.subplots()
plt.axvline(x=0,color='lightgray')
plt.axhline(y=0,color='lightgray')
plt.xlim(-10,10)
plt.ylim(-1,2)
plt.axvline(x=0,color='purple',linestyle='--')
plt.axhline(y=1,color='purple',linestyle='--')
_ = ax.plot(x,y)

# %%
#x

# %% [markdown]
# $$ \lim_{x \to \infty} \frac{25}{x} $$

# %%
def inf_fxn(my_x):
    my_y = 25/my_x
    return my_y

# %%
inf_fxn(1e3)
# Out:
# 0.025

# %%
y = inf_fxn(x)

# %%
fig, ax = plt.subplots()
plt.axvline(x=0,color='lightgray')
plt.axhline(y=0,color='lightgray')
plt.xlim(-10,10)
plt.ylim(-300,300)
_ = ax.plot(x,y)

# %%
left_x = x[x<0]

# %%
right_x = x[x>0]

# %%
left_y = inf_fxn(left_x)

# %%
right_y =inf_fxn(right_x)

# %%
fig, ax = plt.subplots()
plt.axvline(x=0,color='lightgray')
plt.axhline(y=0,color='lightgray')
plt.xlim(-10,10)
plt.ylim(-300,300)
_ = ax.plot(left_x,left_y,c='C0')
ax.plot(right_x,right_y,c='C0')

# %% [markdown]
# ### Computing Derivatives and differentiation

# %%
# y = x*x + 2*x + 2

# %%
def f(my_x):
    my_y = my_x ** 2 + 2*my_x + 2
    return my_y

# %%
y = f(x)

# %%
fig,ax = plt.subplots()
plt.axvline(x=0,color = 'lightgray')
plt.axhline(y=0,color = 'lightgray')
_=ax.plot(x,y)

# %%
#Let's identify the slope, where, say x = 2

# %%
f(2)
# Out:
# 10

# %%
fig,ax = plt.subplots()
plt.axvline(x=0,color = 'lightgray')
plt.axhline(y=0,color = 'lightgray')
plt.scatter(2,10)
_=ax.plot(x,y)

# %% [markdown]
# ### The Delta method uses the difference between two points to calculate the slope.To illustrate this let define another point Q, where say x =5

# %%
f(5)
# Out:
# 37

# %%
fig,ax = plt.subplots()
plt.axvline(x=0,color = 'lightgray')
plt.axhline(y=0,color = 'lightgray')
plt.scatter(2,10)
plt.scatter(5,37,c='orange',zorder = 3)
_=ax.plot(x,y)

# %% [markdown]
# To find the slope $m$ between points $P$ and $Q$:
# $$m = \frac{\text{change in }y}{\text{change in }x} = \frac{\Delta y}{\Delta x} = \frac{y_2 - y_1}{x_2 - x_1} = \frac{37-10}{5-2} = \frac{27}{3} = 9$$

# %%
m = (37-10)/(5-2)
m
# Out:
# 9.0

# %% [markdown]
# To plot the line that passes through $P$ and $Q$, we can rearrange the equation of a line $y = mx + b$ to solve for $b$:
# $$b = y - mx$$

# %%
b = 37 - m*5
b
# Out:
# -8.0

# %%
line_y = m*x + b

# %%
fig,ax = plt.subplots()
plt.axvline(x=0,color = 'lightgray')
plt.axhline(y=0,color = 'lightgray')
plt.scatter(2,10)
plt.scatter(5,37,c='orange',zorder = 3)
plt.ylim(-5,150)
plt.plot(x,line_y,c='orange')
_=ax.plot(x,y)

# %%
#x

# %%
#line_y

# %% [markdown]
# The closer Q becomes to P, the closer the slope m comes to being the true tangent of the point P. Let's demonstrate another point Q at x = 2.1

# %%
#previously Q = 5, now Q = 2.1

# %% [markdown]
# Previously, our $\Delta x$ between $Q$ and $P$ was equal to 3. Now it is much smaller: $$\Delta x = x_2 - x_1 = 2.1 - 2 = 0.1 $$

# %%
f(2.1)
# Out:
# 10.61

# %%
fig,ax = plt.subplots()
plt.axvline(x=0,color = 'lightgray')
plt.axhline(y=0,color = 'lightgray')
plt.scatter(2,10)
plt.scatter(2.1,10.61,c='orange',zorder = 3)
_=ax.plot(x,y)

# %%
m = (10.61-10)/(2.1-2)   # delta(y)/delta(x) => y2-y1/x2-x1
m
# Out:
# 6.099999999999989

# %%
b = 10.61 - m*2.1
b
# Out:
# -2.199999999999978

# %%
line_y = m*x + b
line_y
# Out:
# array([-6.32000000e+01, -6.30778779e+01, -6.29557558e+01, -6.28336336e+01,
#         5.50142142e+01,  5.51363363e+01,  5.52584585e+01,  5.53805806e+01,
#         5.55027027e+01,  5.56248248e+01,  5.57469469e+01,  5.58690691e+01,
#         5.59911912e+01,  5.61133133e+01,  5.62354354e+01,  5.63575576e+01,
#         5.64796797e+01,  5.66018018e+01,  5.67239239e+01,  5.68460460e+01,
#         5.69681682e+01,  5.70902903e+01,  5.72124124e+01,  5.73345345e+01,
#         5.74566567e+01,  5.75787788e+01,  5.77009009e+01,  5.78230230e+01,
#         5.79451451e+01,  5.80672673e+01,  5.81893894e+01,  5.83115115e+01,
#         5.84336336e+01,  5.85557558e+01,  5.86778779e+01,  5.88000000e+01])

# %%
fig,ax = plt.subplots()
plt.axvline(x=0,color = 'lightgray')
plt.axhline(y=0,color = 'lightgray')
plt.scatter(2,10)
plt.scatter(2.1,10.61,c='orange',zorder = 3)
plt.ylim(-5,150)
plt.plot(x,line_y,c='orange',zorder=3)
_=ax.plot(x,y)

# %% [markdown]
# The closer $Q$ becomes to $P$ (i.e., $\Delta x$ approaches 0), the clearer it becomes that the slope $m$ at point $P$ = (2, 10) is equal to 6.

# %% [markdown]
# Let's make $\Delta x$ extremely small, 0.000001, to illustrate this:

# %%
delta_x = 0.000001
delta_x
# Out:
# 1e-06

# %% [markdown]
# Rearranging $\Delta x = x_2 - x_1$, we can calculate $x_2$ for our point $Q$, which is now extremely close to $P$:
# $$x_2 = x_1 + \Delta x$$

# %%
x1 = 2
y1 = 10

# %%
x2 = x1 + delta_x
x2
# Out:
# 2.000001

# %% [markdown]
# $y_2$ for our point $Q$ can be obtained with the usual function $f(x)$:
# $$y_2 = f(x_2)$$

# %%
y2 = f(x2)
y2
# Out:
# 10.000006000001001

# %%
m = (y2-y1)/(x2-x1)
m
# Out:
# 6.000001000088901

# %% [markdown]
# Using Delta Method find the slope of the tangent where x = -1

# %%
x1 = -1

# %%
def f(my_x):
    my_y = my_x ** 2+ 2*my_x + 2
    return my_y

# %%
y1 = f(x1)
y1
# Out:
# 1

# %% [markdown]
# Point P is located at (-1,1)

# %%
delta_x = 0.000001
delta_x
# Out:
# 1e-06

# %%
x2 = x1 + delta_x
x2
# Out:
# -0.999999

# %%
y2 = f(x2)
y2
# Out:
# 1.000000000001

# %% [markdown]
# Quick aside: Pertinent to defining differentiation as an equation, an alternative way to calculate $y_2$ is $f(x + \Delta x)$

# %%
y2 = f(x1 + delta_x)
y2
# Out:
# 1.000000000001

# %% [markdown]
# Point  Q  is at (-0.999999, 1.000000000001), extremely close to  P

# %%
m = (y2-y1)/(x2-x1)
m
# Out:
# 1.0000889005535828e-06

# %% [markdown]
# Therefore, as  x2  becomes infinitely close to  x1 , it becomes clear that the slope  m  at  x1=−1  is equal to zero. Let's plot it out:

# %%
b = y2 - m*x2
b
# Out:
# 1.0000010000889006

# %%
import numpy as np
x = np.linspace(-10,10,1000) #start,finish,n points
#x

# %%
line_y = m*x
#line_y

# %%
y = x*x + 2*x + 2
#y

# %%
fig, ax = plt.subplots()
plt.axvline(x=0, color='lightgray')
plt.axhline(y=0, color='lightgray')
plt.scatter(x1, y1)
plt.scatter(x2, y2, c='orange', zorder=3)
plt.ylim(-5, 150)
plt.plot(x, line_y, c='orange', zorder=3)
_ = ax.plot(x,y)

# %% [markdown]
# As $Q$ becomes infinitely close to $P$:
# * $x_2$ - $x_1$ approaches 0
# * In other words, $\Delta x$ approaches 0
# * This can be denoted as $\Delta x \to 0$

# %% [markdown]
# Using the delta method, we've derived the definition of differentiation from first principles. The derivative of $y$ (denoted $dy$) with respect to $x$ (denoted $dx$) can be represented as:
# $$\frac{dy}{dx} = \lim_{\Delta x \to 0} \frac{\Delta y}{\Delta x}$$

# %% [markdown]
# Expanding $\Delta y$ out to $y_2 - y_1$:
# $$\frac{dy}{dx} = \lim_{\Delta x \to 0} \frac{y_2 - y_1}{\Delta x}$$

# %% [markdown]
# Finally, replacing $y_1$ with $f(x)$ and replacing $y_2$ with $f(x + \Delta x)$, we obtain a common representation of differentiation:
# $$\frac{dy}{dx} = \lim_{\Delta x \to 0} \frac{f(x + \Delta x) - f(x)}{\Delta x}$$

# %% [markdown]
# Let's observe the differentiation equation in action:

# %%
def diff_demo(my_f, my_x, my_delta):
    return (my_f(my_x + my_delta) - my_f(my_x)) / my_delta

# %%
deltas = [1, 0.1, 0.01, 0.001, 0.0001, 0.00001, 0.000001]

# %%
for delta in deltas:
    print(diff_demo(f, 2, delta))
# Out:
# 7.0
# 6.099999999999994
# 6.009999999999849
# 6.000999999999479
# 6.000100000012054
# 6.000009999951316
# 6.000001000927568

# %%
for delta in deltas:
    print(diff_demo(f, -1, delta))
# Out:
# 1.0
# 0.10000000000000009
# 0.009999999999998899
# 0.001000000000139778
# 9.99999993922529e-05
# 1.000000082740371e-05
# 1.000088900582341e-06

# %% [markdown]
# ### Automatic Differentiation

# %% [markdown]
# TensorFlow and PyTorch are the two most popular automatic differentiation libraries.

# %% [markdown]
# Let's use them to calculate  dy/dx  at  x=5  where:

# %% [markdown]
# \$$y = x^2$$

# %% [markdown]
# $$ \frac{dy}{dx} = 2x = 2(5) = 10 $$

# %% [markdown]
# ### Autodiff with PyTorch

# %%
import torch

# %%
x = torch.tensor(5.0)

# %%
x
# Out:
# tensor(5.)

# %%
x.requires_grad_()       #contagiously track gradients through forward pass
# Out:
# tensor(5., requires_grad=True)

# %%
y = x**2

# %%
y
# Out:
# tensor(25., grad_fn=<PowBackward0>)

# %%
y.backward() #use autodiff                      #dy

# %%
x.grad                                          #dx     dy/dx = 10
# Out:
# tensor(10.)

# %% [markdown]
# ### Autodiff with Tensorflow

# %%
import tensorflow as tf

# %%
x = tf.Variable(5.0)
x
# Out:
# <tf.Variable 'Variable:0' shape=() dtype=float32, numpy=5.0>

# %%
with tf.GradientTape() as t:
    t.watch(x)
    y = x**2

# %%
t.gradient(y,x)
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=10.0>
